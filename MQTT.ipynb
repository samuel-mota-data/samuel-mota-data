# %% [markdown]
# <a href="https://colab.research.google.com/github/samuel-mota-data/samuel-mota-data/blob/main/MQTT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Unified Namespace com Automação: Uma Abordagem Inovadora Usando SQL, Power BI, AIoT e Node-RED**

# %% [markdown]
# # **INTRODUÇÃO**

# %% [markdown]
# > # Em um mundo cada vez mais digital, a integração de diferentes tecnologias se torna fundamental para o sucesso dos negócios. Neste artigo, exploraremos como o Unified Namespace pode ser integrado com sistemas de **Automação e ERP, utilizando SQL, Power BI, AIoT e Node-RED** para maximizar a eficiência e a produtividade.

# %% [markdown]
# # **O Projeto**
#
#
#
# > # O Projeto a seguir é uma exemplificação de como essas ferramentas podem e devem auxiliar na implementação de uma Indústria 4.0.

# %% [markdown]
# # **Unified Namespace e Automação**

# %% [markdown]
# > # O Unified Namespace é uma estratégia que permite a integração de diferentes sistemas e tecnologias em uma única plataforma. Isso é especialmente útil na automação, onde diferentes dispositivos e sistemas precisam se comunicar entre si.

# %%
# prompt: colocar imagem local

from IPython.display import Image

# Load the image from the local file system
image_path = '/content/Captura de tela 2024-02-19 083647.png'  # Replace with the actual path to your image
image = Image(filename=image_path)

# Display the image in the notebook
display(image)

# %% [markdown]
# # **Simulando uma Fábrica**
#
#
# > # Através do Simulador CODESYS é possível construir uma estrutura de estudo para aplicação de um sistema CLP completo.

# %%
# prompt: mostrar imagem local

from IPython.display import Image
image = Image(filename='/content/Captura de tela 2024-02-19 064740.png')
display(image)

# %% [markdown]
# # **NODE-RED**

# %% [markdown]
# > # O Node-RED é uma ferramenta de programação visual que facilita a criação de aplicações de IoT. Juntos, eles podem levar a automação a um novo nível.

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (1).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (2).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (4).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (3).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (5).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (12).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (10).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (11).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %% [markdown]
# # **Aplicativos e Conectividade**

# %% [markdown]
# # **SQL SERVER**

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/chrome-capture (13).png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/SQLSERVER.png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)

# %% [markdown]
# # **API - POWER BI ONLINE**

# %%
# prompt: importar 13 images locais separando por celula

# Load and display the first image
image_path = '/content/API POWER BI.png'  # Replace with the actual path to your image
image = Image(filename=image_path)
display(image)
